# %%
# install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (0.112.0)
# Requirement already satisfied: python-dotenv in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\andriigromakov\desktop\epic-light\notes\masha_syncs\claude-study\claude-api\.venv\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)


def chat(messages):
    # Make a request
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

final_answer
# Out:
# 'Unlike classical bits that are either 0 or 1, qubits leverage quantum properties like superposition and entanglement to process vast amounts of information in parallel.'
