# %%
import dotenv, sys
print(sys.executable)        # confirms which Python/venv the kernel uses
print(dotenv.__file__)       # confirms the package actually imported

from dotenv import load_dotenv, find_dotenv
print("dotenv path:", find_dotenv(usecwd=True) or "NO .env FOUND")
load_dotenv()
print("done")
# Out:
# c:\Users\AndriiGromakov\Desktop\epic-light\notes\Masha_syncs\claude-study\claude-api\.venv\Scripts\python.exe
# c:\Users\AndriiGromakov\Desktop\epic-light\notes\Masha_syncs\claude-study\claude-api\.venv\Lib\site-packages\dotenv\__init__.py
# dotenv path: c:\Users\AndriiGromakov\Desktop\epic-light\notes\Masha_syncs\claude-study\claude-api\.env
# done

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
def add_user_message(messages, text):
    user_message = { "role": "user", "content": text }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role": "assistant", "content": text }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=0.5):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    # Make a request
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []


# system="""
# You are a Python engineer who writes very concise code.
# """

# add_user_message(
#     messages=messages,
#     text="Write a python function that checks a string duplicate characters."
#                  )


add_user_message(
    messages=messages,
    text="Generate one sentence movie idea"
                 )


# answer = chat(messages=messages, system=system)
answer = chat(messages=messages, temperature=0.0)
answer
# Out:
# '# Movie Idea\n\nA disgraced archaeologist discovers that the ancient curse she dismissed as folklore is real when her team members begin dying in impossible ways, forcing her to race against time to break the spell before it claims her life.'
